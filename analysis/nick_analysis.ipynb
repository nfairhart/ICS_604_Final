# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.formula.api as smf

np.random.seed(42)

# %%
games_df = pd.read_csv('data/gdelt_nba_games.csv')
pregame_df = pd.read_csv('data/nba_pregame_features.csv')
coverage_df = pd.read_csv('data/gdelt_nba_coverage.csv')
